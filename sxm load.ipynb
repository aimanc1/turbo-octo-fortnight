# %%
pip install nanonispy2
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import nanonispy2 as nap
import matplotlib.pyplot as plt

filename = "Ag111_APT_007.sxm"
sxm = nap.read.Scan(filename)

pixels = sxm.header['scan_pixels']
scan_range = sxm.header['scan_range']
print("pixels:",pixels)
print("range:",scan_range)

Z = sxm.signals['Z']
forward_scan = Z['forward']
back_scan = Z['backward']

plt.imshow(forward_scan)
# Out:
# pixels: [1024 1024]
# range: [1.e-07 1.e-07]
